# %% [raw]
# ---
# title: "Zotero"
# description: "Manage datascience paper"
# date: "01/11/2023"
# categories:
#   - datascience
# image: /images/ai.png
# toc: true
# show_tags: true
# ---

# %% [markdown]
# I have been using [Zotero](https://www.zotero.org/) for a year now.

# %% [markdown]
# ![image.png](attachment:30005832-8f7d-4e45-aee6-c390439a7fd7.png)

# %% [markdown]
# Here is the process I use.

# %% [markdown]
# # Installation and setup

# %% [markdown]
# ## zotero account

# %% [markdown]
# 1st step is to create a [zotero account](https://www.zotero.org/guillaumeramelet/library) from zotero website, quite usefull to sync libraries between multiple zotero installations.

# %% [markdown]
# ## zotero app

# %% [markdown]
# I have installed [zotero app](/posts/2022-12-15-wsl2-fresh-pc.html#zotero) within WSL. For a reason the app on my Windows corporate is not the last one, and cannot sync anymore (I think due to too old chrome version).
# ```bash
# sudo snap install zotero-snap
# # to use CA certificates
# FIREFOX_PROFILE=`find ~/snap/firefox/common/.mozilla/ -name *.default`
# ZOTERO_PROFILE=`find ~/snap/zotero-snap/common/.zotero/ -name *.default`
# cp $FIREFOX_PROFILE/cert9.db $ZOTERO_PROFILE
# cp $FIREFOX_PROFILE/key4.db $ZOTERO_PROFILE
# cp $FIREFOX_PROFILE/pkcs11.txt $ZOTERO_PROFILE
# ```

# %% [markdown]
# ## zotero browser extension

# %% [markdown]
# From zotero website, install [connectors](https://www.zotero.org/download/connectors)
#
# ![image.png](attachment:90a8b17a-ae98-412d-8f54-194b773b5b2e.png)

# %% [markdown]
# For a reason, install browser connector from zotero app doesn't do anything here.

# %% [markdown]
# ![image.png](attachment:774e25b1-fc5d-4664-b848-98375adb619f.png)

# %% [markdown]
# # How to use it

# %% [markdown]
# As soon as installed in Firefox, the easiest and more efficient way is to navigate sources with Firefox and Click on Zotero add-on **Save to Zotero**

# %% [markdown]
# ![image.png](attachment:da99f0fa-9a3a-421a-91a2-99dc0b44c5e2.png)

# %% [markdown]
# It gets all metadata and download PDFs.

# %% [markdown]
# ## Note

# %% [markdown]
# We should have the same behaviour from app by using the magic wand but for a certificate reason it fails ![image.png](attachment:4f61a970-5da0-42c6-b880-3acc5be9b68f.png)

# %% [markdown]
# And doing the same from zotero website gets metadata but not the pdfs.

# %% [markdown]
# Because of that I will focus on this process based on browser add-on.
