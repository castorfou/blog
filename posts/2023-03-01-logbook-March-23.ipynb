# %% [raw]
# ---
# title: "Logbook for March 23"
# description: ""
# date: "03/01/2023"
# categories:
#   - logbook
# image: /images/logbook.jpg
# toc: true
# show_tags: true
# ---

# %% [markdown]
# # Week 9 - March 23

# %% [markdown]
# ## Friday 03/03

# %% [markdown]
# ### tilix

# %% [markdown]
# Will use [tilix](/posts/2022-12-15-wsl2-fresh-pc.html#tilix) as terminal in WSL
#
# ![image.png](attachment:bb2339c4-070e-4528-a11f-9e85b3bc3002.png)

# %% [markdown]
# ### quarto

# %% [markdown]
# bug with version 1.3.242, switched back to stable version
#
# see [ERROR: File name too longERROR: File name too long](/posts/2022-09-16-migrate%20blog%20from%20nbdev%20to%20quarto.html#bug-error-file-name-too-long-os-error-36-when-rendering-with-v1.3.242)

# %% [markdown]
# ### zsh snap nautilus

# %% [markdown]
# It has already hapenned once with bash and agin now that I have switched to zsh.
#
# I don't see snap apps from nautilus (for example to edit a text file with sublime-text)
#
# Option was to ensure to have `XDG_DATA_DIRS` variable set up. But here it doesn't help.
#
# https://askubuntu.com/questions/910821/programs-installed-via-snap-not-showing-up-in-launcher

# %% [markdown]
# # Week 10 - March 23

# %% [markdown]
# ## Wednesday 03/08

# %% [markdown]
# ### homebrew brew

# %% [markdown]
# Running through gitlab news, I have met `glab`which is a CLI for gitlab
#
# <img src="data:image/png;base64,..." alt="image" iscopyblocked="false">

# %% [markdown]
# and it installs through brew.
#
# Brew is a package manager for macos, linux, windows.
#
# I followed this doc https://www.how2shout.com/linux/install-brew-on-wsl-windows-subsystem-for-linux/ to install it
#
# ```bash
# /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install.sh)"
#
# #and add this to .zshrc
# eval $(/home/linuxbrew/.linuxbrew/bin/brew shellenv)
#
# #you can then test it
# > brew doctor
# Your system is ready to brew.
# ```

# %% [markdown]
# ### glab

# %% [markdown]
# ```bash
# brew install glab
# ```
#
# https://ghcr.io/v2/homebrew/core/glab/manifests/1.25.3 unfortunately not accessible from my PC (blocked by company policy)
