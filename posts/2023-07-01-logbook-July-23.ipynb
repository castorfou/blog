# %% [raw]
# ---
# title: "Logbook for July 23"
# description: ""
# date: "07/01/2023"
# categories:
#   - logbook
# image: /images/logbook.jpg
# toc: true
# show_tags: true
# ---

# %% [markdown]
# # Week 29 - July 23

# %% [markdown]
# ## Friday 07/21

# %% [markdown]
# **datashader** or how to use plotly/bokeh with millions of points

# %% [markdown]
# I should create a full entry with this experiment.
#
# Waiting for it, I tried [holoviz](https://holoviz.org/) which is a way to seamlessly integrate various graph libs such as hvplot and datashader.
#
# ![image.png](attachment:8c910119-b9b0-4c8c-b884-9eeca7c6afe7.png)

# %% [markdown]
# I have started to play with the [tutorial](https://holoviz.org/tutorial/index.html), and what I would likely use is this hvplot/datashader combo which allows to quickly display millions of points in a graph without any performance issue. And when zooming in, it gets more details.
#
# This works perfectly when executed from the tutorial environment. But I have not succeeded in making it work on my own environments.
#
# I have posted a in their [forum](https://discourse.holoviz.org/t/minimal-installation-to-have-hvplot-datashader/5748).
