# %% [raw]
# ---
# title: "Icon support in WSL / WSLg with native linux applications [fixed with WSL v1.1.7, broken again with WSL v1.2.x]"
# description: "some icons in taskbar for linux applications are defaulting to Tux"
# date: "03/03/2023"
# categories:
#   - wsl
# image: /images/icons/wsl2.jpeg
# toc: true
# show_tags: true
# ---

# %% [markdown]
# # Problem

# %% [markdown]
# As I have explained in https://github.com/microsoft/wslg/issues/944
#
# some icons are missing and defaulting to Tux
#
# ![image.png](attachment:f4d20218-2ccb-43bd-9573-084768c881bc.png)

# %% [markdown]
# # Update April/21 23: with WSL v1.2.x, this has been broken again.
#
# https://github.com/microsoft/wslg/issues/944#issuecomment-1517301808
#
# ![image.png](attachment:4682db7e-285c-4af4-bdfe-ec2bb804bd2c.png)
#
# Here is the [changelog](https://github.com/microsoft/WSL/releases/tag/1.2.5) of WSL 1.2.5

# %% [markdown]
# # Update April/4 23: with WSL v1.1.7, this has been fixed.
#
# ![image.png](attachment:76b3e1cf-53b7-4cf0-a5ff-ec512a73945d.png)
#
# Here is the [changelog](https://github.com/microsoft/WSL/releases/tag/1.1.7) of WSL 1.1.7

# %% [markdown]
# # What works

# %% [markdown]
# ## In Start Menu

# %% [markdown]
# Now that X11 apps are inserted into Windows Start Menu
#
# ![image.png](attachment:a617f802-d178-4441-8528-717398d86a4f.png)

# %% [markdown]
# ### shortcuts to X11 apps
#
# Those entries are like other native windows ones.
#
# They are located at `%USERPROFILE%\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\ubuntu-22.04` (where `ubuntu-22.04` is the name of my distrib)
#
# and we can update those icons (right click > Plus > Open file location)
#
# ![image.png](attachment:c197a71e-28d6-484a-b490-821caf7de8cd.png)
# `%USERPROFILE%\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\ubuntu-22.04`

# %% [markdown]
# ### add new icons
# We can now right click these entries, update icon. When installing apps, WSLg is creating icon entries into `%USERPROFILE%\AppData\Local\Temp\WSLDVCPlugin\ubuntu-22.04\` (where `ubuntu-22.04` is still the name of my distrib)
# I can add mine in that location
#
# ![image.png](attachment:18769d11-1a06-4df1-a1ab-b360e5983027.png)
# `%USERPROFILE%\AppData\Local\Temp\WSLDVCPlugin\ubuntu-22.04\`

# %% [markdown]
# ### (optional) from png to icon with zsh

# %% [markdown]
# I can't believe we cannot use png files as icon in Windows.
#
# However how to easily turn png file to ico file using zsh?
#
# Create `png2ico.zsh` in `~/bin`
# ```zsh
# #!/usr/bin/zsh
# png2ico () {
#     local i="${1}" o="${2:-${1:r}.ico}"
#     convert "$i" -define icon:auto-resize=256,128,64,48,32,16 "$o"
# }
# ```
#
# Create ico from png
# ```zsh
# source ~/bin/png2ico.zsh
# png2ico tilix_icon.png
# ```
# ![image.png](attachment:98f62211-3fbd-44a3-b21f-87e1a77739ee.png)
# ico file created
#
# You can move it to `%USERPROFILE%\AppData\Local\Temp\WSLDVCPlugin\ubuntu-22.04\`, and update Tilix entry from `%USERPROFILE%\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\ubuntu-22.04` to use this new ico file

# %% [markdown]
# We can pin them in the Task bar, and in the Start screen
#
# ![image.png](attachment:82712699-c3f4-4b06-8047-be47c0c4adde.png)
#
#
# ![image.png](attachment:e479c3cc-4eb5-49ae-a77b-13e489d3d090.png)
#
# but when running them, this is a different story
#
# ![image.png](attachment:cd2aefb6-799f-4d0f-b812-fa2f63a7c80f.png)

# %% [markdown]
# # What works a little bit
